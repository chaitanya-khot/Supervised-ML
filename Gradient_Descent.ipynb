# %% [markdown]
# <a href="https://colab.research.google.com/github/thisiskhot/Supervised-ML/blob/main/Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Definition:
# Gradient Descent is an algorithm that solves optimization problems using first-order iterations. Since it is designed to find the local minimum of a differential function, gradient descent is widely used in machine learning models to find the best parameters that minimize the model's cost function (or any function in general).

# %% [markdown]
# It minimizes the function J(w,b) to find $min_{w,b}$ J(w,b)

# %% [markdown]
# Initially, we start with a w and b and we keep changing them to reduce J(w, b)until we settle at or near a minimum.

# %% [markdown]
# **Local minima:** The point in a curve which is minimum when compared to its preceding and succeeding points is called local minima. <br>
# **Global minima:** The point in a curve which is minimum when compared to all points in the curve is called Global Minima.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Alpha- learning rate (how big of a step you're taking downhill) <br>
# d/dw J(w, b)- derivative term of the cost function

# %% [markdown]
# **Remember to update w after implementing temp w and temp b** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Useful links- https://blog.paperspace.com/intro-to-optimization-in-deep-learning-gradient-descent/#:~:text=Gradient%20descent%20is%20driven%20by,point%20in%20a%20local%20region.
